# %%
import pandas as pd
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Загрузка и знакомство с данными

# %% [markdown]
# Для работы вам понадобятся предобработанные данные датасета для «Прогноза популярности статьи на Хабре».

# %%
url = 'https://raw.githubusercontent.com/miptgirl/habra_materials/master/prophet/howpop_train.csv'
df = pd.read_csv(url)
df.head()
# Out:
#                                 url        domain  post_id  \
# 0  https://habrahabr.ru/post/18284/  habrahabr.ru    18284
# 1  https://habrahabr.ru/post/18285/  habrahabr.ru    18285
# 2  https://habrahabr.ru/post/18286/  habrahabr.ru    18286
# 3  https://habrahabr.ru/post/18291/  habrahabr.ru    18291
# 4  https://geektimes.ru/post/18294/  geektimes.ru    18294
#
#              published      author     flow  polling  content_len  \
# 0  2008-01-01 18:19:00      @Tapac  develop    False         4305
# 1  2008-01-01 18:30:00  @DezmASter   design    False         7344
# 2  2008-01-01 18:34:00  @DezmASter   design    False         8431
# 3  2008-01-02 01:32:00    @Taoorus   design    False         5662
# 4  2008-01-02 14:34:00    @dennydo      NaN    False         3706
#
#                                                title  comments  favs  views  \
# 0     Новогодний подарок блоггерам — WordPress 2.3.2         0     0    236
# ...

# %%
df.shape
# Out:
# (134137, 17)

# %%
df.head(3).T
# Out:
#                                                                0  \
# url                             https://habrahabr.ru/post/18284/
# domain                                              habrahabr.ru
# post_id                                                    18284
# published                                    2008-01-01 18:19:00
# author                                                    @Tapac
# flow                                                     develop
# polling                                                    False
# content_len                                                 4305
# title             Новогодний подарок блоггерам — WordPress 2.3.2
# comments                                                       0
# favs                                                           0
# views                                                        236
# votes_plus                                                     0
# ...

# %% [markdown]
# Избавимся сразу от переменных, названия которых заканчиваются на `_lognorm`. Выберем их с помощью `filter()` и удалим drop-ом:

# %%
df.drop(filter(lambda c: c.endswith('_lognorm'), df.columns), 
        axis = 1,       # axis = 1: столбцы 
        inplace = True) # избавляет от необходимости сохранять датасет

# %%
df.describe().T
# Out:
#                 count           mean           std      min       25%  \
# post_id      134137.0  181307.054265  81766.350702  18284.0  115565.0
# content_len  134137.0    7516.929699   8724.771640      1.0    2179.0
# comments     134137.0      39.625994     62.398958      0.0       7.0
# favs         134137.0      71.999866    145.854135      0.0       8.0
# views        134137.0   16631.013084  31479.819691      3.0    2100.0
# votes_plus   133566.0      35.536888     42.461073      0.0      11.0
# votes_minus  133566.0       8.050035     11.398282      0.0       2.0
#
#                   50%       75%        max
# post_id      182666.0  257401.0   314088.0
# content_len    4949.0    9858.0   352471.0
# comments         19.0      48.0     2266.0
# favs             27.0      78.0     8718.0
# views          7600.0   18700.0  1730000.0
# votes_plus       22.0      45.0     1466.0
# votes_minus       5.0      10.0      445.0

# %%
df.describe().T
# Out:
#                 count           mean           std      min       25%  \
# post_id      134137.0  181307.054265  81766.350702  18284.0  115565.0
# content_len  134137.0    7516.929699   8724.771640      1.0    2179.0
# comments     134137.0      39.625994     62.398958      0.0       7.0
# favs         134137.0      71.999866    145.854135      0.0       8.0
# views        134137.0   16631.013084  31479.819691      3.0    2100.0
# votes_plus   133566.0      35.536888     42.461073      0.0      11.0
# votes_minus  133566.0       8.050035     11.398282      0.0       2.0
#
#                   50%       75%        max
# post_id      182666.0  257401.0   314088.0
# content_len    4949.0    9858.0   352471.0
# comments         19.0      48.0     2266.0
# favs             27.0      78.0     8718.0
# views          7600.0   18700.0  1730000.0
# votes_plus       22.0      45.0     1466.0
# votes_minus       5.0      10.0      445.0

# %%
df.describe(include = ['object', 'bool']).T # бинарные и категориальные переменные
# Out:
#             count  unique                                          top    freq
# url        134137  134137            https://geektimes.ru/post/251676/       1
# domain     134137       2                                 habrahabr.ru   97048
# published  134137  130291                          2011-06-14 15:52:00      39
# author      97657   22077                                      @alizar    5292
# flow        97048       6                                      develop   53318
# polling    134137       2                                        False  129412
# title      134137  133628  Интересные события, произошедшие в выходные      56

# %%
# настройка внешнего вида графиков в seaborn
sns.set_style("dark")
sns.set_palette("RdBu")
sns.set_context("notebook", font_scale = 1.5, 
                rc = { "figure.figsize" : (15, 5), "axes.titlesize" : 18 })

# %% [markdown]
# Столбец published (время публикации) содержит строки. Чтобы мы могли работать с этими данными как с датой/временем публикации, приведём их к типу datetime:

# %%
print(df.published.dtype)
df['published'] = pd.to_datetime(df.published, yearfirst=True)
print(df.published.dtype)
# Out:
# object
# datetime64[ns]

# %% [markdown]
# Создадим несколько столбцов на основе данных о времени публикации:

# %%
df['year'] = [d.year for d in df.published]
df['month'] = [d.month for d in df.published]

df['dayofweek'] = [d.isoweekday() for d in df.published]
df['hour'] = [d.hour for d in df.published]

# %%
df.head(3)
# Out:
#                                 url        domain  post_id  \
# 0  https://habrahabr.ru/post/18284/  habrahabr.ru    18284
# 1  https://habrahabr.ru/post/18285/  habrahabr.ru    18285
# 2  https://habrahabr.ru/post/18286/  habrahabr.ru    18286
#
#             published      author     flow  polling  content_len  \
# 0 2008-01-01 18:19:00      @Tapac  develop    False         4305
# 1 2008-01-01 18:30:00  @DezmASter   design    False         7344
# 2 2008-01-01 18:34:00  @DezmASter   design    False         8431
#
#                                                title  comments  favs  views  \
# 0     Новогодний подарок блоггерам — WordPress 2.3.2         0     0    236
# 1  Сумасшедшие яйца, или сервис для отслеживания ...         1     1    353
# 2  Сумасшедшие яйца, или сервис для отслеживания ...        47    72   1200
#
#    votes_plus  votes_minus  year  month  dayofweek  hour
# 0         0.0          0.0  2008      1          2    18
# ...

# %% [markdown]
# Теперь Ваша очередь. В каждом пункте предлагается построить картинку и с ее помощью ответить на вопрос. Конечно, можно попытаться ответить на все вопросы только с Pandas, без картинок, но я советую Вам потренироваться строить (красивые) визуализации.

# %% [markdown]
# ## 1. В каком месяце (и какого года) было больше всего публикаций?

# %% [markdown]
# * март 2016
# * март 2015
# * апрель 2015
# * апрель 2016

# %%
df['mon_year'] = [(str(d.month) + '-' + str(d.year)) for d in df.published]
df.groupby(['mon_year'])['mon_year'].count().sort_values(ascending=False).head().plot()
# в марте 2015 больше всего публикаций

# %% [markdown]
# ## 2. Проанализируйте публикации в месяце из предыдущего вопроса

# %% [markdown]
# Выберите один или несколько вариантов:
#
# * Один или несколько дней сильно выделяются из общей картины
# * На хабре всегда больше статей, чем на гиктаймсе
# * По субботам на гиктаймс и на хабрахабр публикуют примерно одинаковое число статей
#
# Подсказки: постройте график зависимости числа публикаций от дня; используйте параметр hue; не заморачивайтесь сильно с ответами и не ищите скрытого смысла :)

# %%
df_mon = df[df.mon_year == '3-2015']
df_mon['day'] = [p.day for p in df_mon.published]
fig = plt.figure(figsize=(12,8))
sns.countplot(x = 'day', data = df_mon)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
fig = plt.figure(figsize=(12,8))
sns.countplot(x = 'day', hue = 'domain', data = df_mon) 
# есть два дня когда гиктаймсе статей больше

# %%
fig = plt.figure(figsize=(10,7))
sns.countplot(x = 'dayofweek', hue = 'domain', data = df_mon) 
# да, в субботу публикуют почти одинаковое количество статей

# %% [markdown]
# ## 3. Когда лучше всего публиковать статью?

# %% [markdown]
# * Больше всего просмотров набирают статьи, опубликованные в 12 часов дня
# * У опубликованных в 10 утра постов больше всего комментариев
# * Больше всего просмотров набирают статьи, опубликованные в 6 часов утра
# * Максимальное число комментариев на гиктаймсе набрала статья, опубликованная в 9 часов вечера
# * На хабре дневные статьи комментируют чаще, чем вечерние

# %%
fig = plt.figure(figsize=(10,7))
df.groupby('hour')['views'].mean().plot() 
# Больше всего просмотров набирают статьи, опубликованные в 6 часов утра

# %%
fig = plt.figure(figsize=(10,7))
df.groupby('hour')['comments'].mean().plot(kind='bar')

# %%
fig = plt.figure(figsize=(10,7))
df[df.domain == 'geektimes.ru'].groupby('hour')['comments'].mean().plot()

# %%
fig = plt.figure(figsize=(10,7))
df[df.domain == 'habrahabr.ru'].groupby('hour')['comments'].mean().plot()

# %% [markdown]
# ## 4. Кого из топ-20 авторов чаще всего минусуют?¶

# %% [markdown]
# * @Mordatyj
# * @Mithgol
# * @alizar
# * @ilya42

# %%
top_authors = ['@Mordatyj','@Mithgol', '@alizar', '@ilya42']
df[df.author.isin(top_authors)].groupby('author')['votes_minus'].mean().plot()

# %% [markdown]
# ## 5. Сравните субботы и понедельники

# %% [markdown]
# Правда ли, что по субботам авторы пишут в основном днём, а по понедельникам — в основном вечером?

# %%
fig = plt.figure(figsize=(15,10))
sns.countplot(y = 'hour', hue = 'dayofweek', data = df[df.dayofweek.isin([1, 6])])
# по субботам авторы пишут в основном днём и вечером, а по понедельникам — в основном днем
